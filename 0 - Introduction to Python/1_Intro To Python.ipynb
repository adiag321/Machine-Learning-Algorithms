# %% [markdown]
# ### 1. String manipuation

# %%
text='Ice cream'
## text[0]='S' #String is immutable
print(text[4:])
# Out:
# cream

# %%
address='''House #51 Village:Gilatala Nazirpur, Pirojpur Bangladesh'''
phn_no=17471234

    #need same type to concate
print(address+"\nPhone:"+str(phn_no))
# Out:
# House #51 Village:Gilatala Nazirpur, Pirojpur Bangladesh
# House #51 Village:Gilatala Nazirpur, Pirojpur Bangladesh
# Phone:17471234

# %% [markdown]
# ### 2. List Manipulation

# %%
items=['bread','pasta','fruits']
print(items[-1])
# Out:
# fruits

# %%
items.append('butter')
print(items)
# Out:
# ['bread', 'pasta', 'fruits', 'butter']

# %%
items.remove('butter')
items.insert(1,'butter')
print(items)
# Out:
# ['bread', 'butter', 'pasta', 'fruits']

# %%
print(len(items))
print('bread' in items)
# Out:
# 4
# True

# %% [markdown]
# ### Tuple Manipulation

# %%
#Touple is a list of values group together 
#All values have several meaning
point=(3,7) #x,y axis
point[1]
# Out:
# 7

# %%
##point[1]=14 #Tuple object is immutable
address=('24 aveneu','Motijheel',1214) #can store different types
print(address)
# Out:
# ('24 aveneu', 'Motijheel', 1214)
