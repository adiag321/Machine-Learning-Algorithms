# %%
#Creating a dictionary
marks = {'history':45,'Geography':54,'Hindi':56}
marks
# Out:
# {'history': 45, 'Geography': 54, 'Hindi': 56}

# %%
# access elements
marks['Geography']
# Out:
# 54

# %%
#adding elements
marks['english'] = 47
marks
# Out:
# {'history': 45, 'Geography': 54, 'Hindi': 56, 'english': 47}

# %%
marks.update({'Chemistry':89,'Physics':98})
marks
# Out:
# {'history': 45,
#  'Geography': 54,
#  'Hindi': 56,
#  'english': 47,
#  'Chemistry': 89,
#  'Physics': 98}

# %%
del marks['Hindi']
marks
# Out:
# {'history': 45, 'Geography': 54, 'english': 47, 'Chemistry': 89, 'Physics': 98}

# %%
#Iterating {Key: Value}
for key in marks:
    print("Key:", key, '--',"Value:", marks[key])
# Out:
# Key: history -- Value: 45
# Key: Geography -- Value: 54
# Key: english -- Value: 47
# Key: Chemistry -- Value: 89
# Key: Physics -- Value: 98

# %%
for k,v in marks.items():
    print("Key:",k, '--', "Value/Item:",v)
# Out:
# Key: history -- Value/Item: 45
# Key: Geography -- Value/Item: 54
# Key: english -- Value/Item: 47
# Key: Chemistry -- Value/Item: 89
# Key: Physics -- Value/Item: 98
