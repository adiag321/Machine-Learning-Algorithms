# %% [markdown]
# #### Watch the video on [Rob Mulla](https://www.youtube.com/@robmulla) Youtube Channel
# The video link is [https://www.youtube.com/watch?v=DkjCaAMBGWM](https://www.youtube.com/watch?v=DkjCaAMBGWM)
#
# 1. Dataframe basics
# 2. Subsetting Columns
# 3. Select as series vs dataframe
# 4. iloc for Data filtering
# 5. LOC filter expressions
# 6. Summary Statistics
# 7. Aggregate function
# 8. Summarize Categorical Variables
# 9. Rank, Shift, Cumsum
# 10. Rolling methods (IMP)
# 11. Groupby
# 12. New columns
# 13. Sorting
# 14. Missing data
# 15. Concat
# 16. Merge dataframes
# 17. Merge suffixes
# 18. Joins
# 19. isin()
# 20. Dropna()
# 21. Pivot Table

# %%
import pandas as pd
import sys
import os
import warnings
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", 500)

sys.path.insert(0, fr'D:\OneDrive - Northeastern University\Jupyter Notebook\Machine Learning Automations')
import Reading_csv_files as rd
rd.read_csv()
# Out:
# Select 1 if you are working in Windows Laptop and 2 for MacBook: 1
# Location changed for Windows
# Updated Location is: D:/OneDrive - Northeastern University/Data-Science-datasets

# %% [markdown]
# ### Reading from file

# %%
df = pd.read_parquet("./Flight Status Prediction/Combined_Flights_2022.parquet")
df.head(3)
# Out:
#   FlightDate                                    Airline Origin Dest  \
# 0 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT  DEN
# 1 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL  IAH
# 2 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
#
#    Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# 0      False     False        1133   1123.0              0.0     -10.0
# 1      False     False         732    728.0              0.0      -4.0
# 2      False     False        1529   1514.0              0.0     -15.0
#
#    ArrTime  ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  \
# 0   1228.0              0.0     40.0            72.0               65.0
# 1    848.0              0.0     55.0            77.0               80.0
# 2   1636.0              0.0     47.0            70.0               82.0
#
#    Distance  Year  Quarter  Month  DayofMonth  DayOfWeek  \
# ...

# %% [markdown]
# #### 18. Dropna()

# %%
df.dropna(how="any").head()
# Out:
#   FlightDate                                    Airline Origin Dest  \
# 0 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT  DEN
# 1 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL  IAH
# 2 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 3 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH  GPT
# 4 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
#
#    Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# 0      False     False        1133   1123.0              0.0     -10.0
# 1      False     False         732    728.0              0.0      -4.0
# 2      False     False        1529   1514.0              0.0     -15.0
# 3      False     False        1435   1430.0              0.0      -5.0
# 4      False     False        1135   1135.0              0.0       0.0
#
#    ArrTime  ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  \
# ...

# %%
df.fillna(value=5)
# Out:
#        FlightDate                                    Airline Origin Dest  \
# 0      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT  DEN
# 1      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL  IAH
# 2      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 3      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH  GPT
# 4      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# ...           ...                                        ...    ...  ...
# 590537 2022-03-31                          Republic Airlines    MSY  EWR
# 590538 2022-03-17                          Republic Airlines    CLT  EWR
# 590539 2022-03-08                          Republic Airlines    ALB  ORD
# 590540 2022-03-25                          Republic Airlines    EWR  PIT
# 590541 2022-03-07                          Republic Airlines    EWR  RDU
#
#         Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# ...

# %% [markdown]
# #### 19. Pivot Table

# %%
## In which month does have an average Airtime with respect to each state
pd.pivot_table(df, values="AirTime", index=["OriginStateName"], columns=["Month"]).head()
# Out:
# Month                     1           2           3           4           5  \
# OriginStateName
# Alabama           76.446371   77.018860   77.911061   77.845798   77.613706
# Alaska           100.963512  100.402462  102.170420  103.943352  111.655682
# Arizona          120.843414  117.692370  120.767383  116.965798  118.088300
# Arkansas          78.733272   79.786184   77.311874   79.592762   81.409532
# California       126.854463  125.263293  128.383055  125.056217  125.551996
#
# Month                     6           7
# OriginStateName
# Alabama           75.816998   75.563501
# Alaska           126.387915  127.332310
# Arizona          116.198359  117.776605
# Arkansas          80.366809   80.413661
# California       124.769284  127.355536

# %% [markdown]
# #### 20. Map()

# %%
df['Diverted'] = df['Diverted'].map({False:0, True:1})
df['Diverted'].value_counts()
# Out:
#        FlightDate                Airline Origin Dest  Cancelled  Diverted  \
# 399529 2022-05-29              Envoy Air    DFW  AUS      False         0
# 429120 2022-03-01  United Air Lines Inc.    DEN  LGA      False         0
# 242781 2022-07-06          Allegiant Air    BNA  PGD      False         0
# 359306 2022-02-20       Spirit Air Lines    MKE  LAX      False         0
# 19242  2022-05-09  SkyWest Airlines Inc.    SMF  SLC      False         0
#
#         CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# 399529         845    842.0              0.0      -3.0    933.0
# 429120         730    727.0              0.0      -3.0   1253.0
# 242781        1334   1330.0              0.0      -4.0   1623.0
# 359306        1110   1113.0              3.0       3.0   1326.0
# 19242          615    613.0              0.0      -2.0    838.0
#
#         ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  Distance  \
# ...

# %% [markdown]
# ### 21. Convert continuous data into categorical data (alternative)
# We can use CUT(), but here is an alternative

# %%
## Extarcting Day from date
import datetime as dt
df['Day'] = df['FlightDate'].dt.day

# %%
pd.cut(df['Day'], bins=[0,7,14,21,30], labels = ['1st week', '2nd week', '3rd week', '4th Week']).sample(10)
# Out:
# 217519    3rd week
# 453659    3rd week
# 536393    2nd week
# 95666     2nd week
# 482736    1st week
# 100763    1st week
# 326542    2nd week
# 165787    4th Week
# 500795    4th Week
# 465425    2nd week
# Name: Day, dtype: category
# Categories (4, object): ['1st week' < '2nd week' < '3rd week' < '4th Week']

# %% [markdown]
# ### 22. Crosstab()

# %%
## Which State has the most number of flights departing on which month
pd.crosstab(df.Month, df.OriginStateName)
# Out:
# OriginStateName  Alabama  Alaska  Arizona  Arkansas  California  Colorado  \
# Month
# 1                   2627    2871    15883      2270       55750     25921
# 2                   2474    2708    15147      2029       51658     23956
# 3                   2727    3121    17429      2142       58270     26389
# 4                   2854    3153    16515      2212       60056     24140
# 5                   2989    3592    15597      2419       62846     25475
# 6                   2865    4285    15351      2386       64338     26918
# 7                   2882    4632    15901      2399       66466     27913
#
# OriginStateName  Connecticut  Delaware  Florida  Georgia  Hawaii  Idaho  \
# Month
# 1                       1855         9    52913    27648    9681   2753
# 2                       1814         8    49101    24963    8475   2476
# 3                       2012         8    57713    28966   10290   2683
# ...

# %% [markdown]
# #### Ordered categories must be specified independent of the data

# %%
df = pd.DataFrame({'ID':[100, 101, 102, 103],'quality':['good', 'very good', 'good', 'excellent']})
df
# Out:
#     ID    quality
# 0  100       good
# 1  101  very good
# 2  102       good
# 3  103  excellent

# %%
# old way to create an ordered category (deprecated)
df.quality.astype('category', categories=['good', 'very good', 'excellent'], ordered=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 # old way to create an ordered category (deprecated)
# ----> 2 df.quality.astype('category', categories=['good', 'very good', 'excellent'], ordered=True)
#
# TypeError: NDFrame.astype() got an unexpected keyword argument 'categories'

# %%
# new way to create an ordered category
from pandas.api.types import CategoricalDtype
quality_cat = CategoricalDtype(['good', 'very good', 'excellent'], ordered=True)
df['quality'] = df.quality.astype(quality_cat)
df.quality
# Out:
# 0         good
# 1    very good
# 2         good
# 3    excellent
# Name: quality, dtype: category
# Categories (3, object): ['good' < 'very good' < 'excellent']
