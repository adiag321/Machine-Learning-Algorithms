# %% [markdown]
# ### Simple Experiment Tracking
#
# In this notebook, we will track the experiments and store the model artifacts locally and not in MLFlow/AWS Cloud

# %%
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
# Step 1: Create an imbalanced binary classification dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=2, n_redundant=8, 
                           weights=[0.9, 0.1], flip_y=0, random_state=42)

np.unique(y, return_counts=True)
# Out:
# (array([0, 1]), array([900, 100]))

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %%
# Define the model hyperparameters
params = {
    "solver": "lbfgs",
    "max_iter": 1000,
    "multi_class": "auto",
    "random_state": 8888,
}

# Train the model
lr = LogisticRegression(**params)
lr.fit(X_train, y_train)

# Predict on the test set
y_pred = lr.predict(X_test)

report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       270
#            1       0.62      0.50      0.56        30
#
#     accuracy                           0.92       300
#    macro avg       0.79      0.73      0.76       300
# weighted avg       0.91      0.92      0.92       300

# %%
report_dict = classification_report(y_test, y_pred, output_dict=True)
report_dict
# Out:
# {'0': {'precision': 0.9456521739130435,
#   'recall': 0.9666666666666667,
#   'f1-score': 0.9560439560439561,
#   'support': 270.0},
#  '1': {'precision': 0.625,
#   'recall': 0.5,
#   'f1-score': 0.5555555555555556,
#   'support': 30.0},
#  'accuracy': 0.92,
#  'macro avg': {'precision': 0.7853260869565217,
#   'recall': 0.7333333333333334,
#   'f1-score': 0.7557997557997558,
#   'support': 300.0},
#  'weighted avg': {'precision': 0.9135869565217392,
#   'recall': 0.92,
#   'f1-score': 0.9159951159951161,
#   'support': 300.0}}

# %% [markdown]
# ### Using MLFlow

# %%
# !pip install mlflow
import mlflow
# Out:
# Requirement already satisfied: mlflow in c:\users\adiag\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: mlflow-skinny==3.8.1 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow) (3.8.1)
# Requirement already satisfied: mlflow-tracing==3.8.1 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow) (3.8.1)
# Requirement already satisfied: Flask-CORS<7 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow) (6.0.2)
# Requirement already satisfied: Flask<4 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow) (3.1.0)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow) (1.18.1)
# Requirement already satisfied: cryptography<47,>=43.0.0 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow) (44.0.1)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: huey<3,>=2.5.0 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow) (2.6.0)
# Requirement already satisfied: matplotlib<4 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow) (3.10.0)
# Requirement already satisfied: numpy<3 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow) (2.1.3)
# Requirement already satisfied: pandas<3 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow) (2.2.3)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow) (19.0.0)
# Requirement already satisfied: scikit-learn<2 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow) (1.6.1)
# Requirement already satisfied: scipy<2 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow) (1.15.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow) (2.0.39)
# Requirement already satisfied: waitress<4 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<7,>=5.0.0 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow-skinny==3.8.1->mlflow) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow-skinny==3.8.1->mlflow) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow-skinny==3.8.1->mlflow) (3.0.0)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow-skinny==3.8.1->mlflow) (0.78.0)
# Requirement already satisfied: fastapi<1 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow-skinny==3.8.1->mlflow) (0.128.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow-skinny==3.8.1->mlflow) (3.1.43)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow-skinny==3.8.1->mlflow) (8.5.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow-skinny==3.8.1->mlflow) (1.39.1)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow-skinny==3.8.1->mlflow) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow-skinny==3.8.1->mlflow) (1.39.1)
# Requirement already satisfied: packaging<26 in c:\users\adiag\appdata\roaming\python\python313\site-packages (from mlflow-skinny==3.8.1->mlflow) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow-skinny==3.8.1->mlflow) (6.33.4)
# Requirement already satisfied: pydantic<3,>=2.0.0 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow-skinny==3.8.1->mlflow) (2.10.3)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow-skinny==3.8.1->mlflow) (1.1.0)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow-skinny==3.8.1->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow-skinny==3.8.1->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow-skinny==3.8.1->mlflow) (0.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow-skinny==3.8.1->mlflow) (4.14.1)
# Requirement already satisfied: uvicorn<1 in c:\users\adiag\anaconda3\lib\site-packages (from mlflow-skinny==3.8.1->mlflow) (0.40.0)
# Requirement already satisfied: Mako in c:\users\adiag\anaconda3\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: colorama in c:\users\adiag\appdata\roaming\python\python313\site-packages (from click<9,>=7.0->mlflow-skinny==3.8.1->mlflow) (0.4.6)
# Requirement already satisfied: cffi>=1.12 in c:\users\adiag\anaconda3\lib\site-packages (from cryptography<47,>=43.0.0->mlflow) (1.17.1)
# Requirement already satisfied: google-auth~=2.0 in c:\users\adiag\anaconda3\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow) (2.40.3)
# Requirement already satisfied: pywin32>=304 in c:\users\adiag\appdata\roaming\python\python313\site-packages (from docker<8,>=4.0.0->mlflow) (311)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\adiag\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow) (1.26.20)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in c:\users\adiag\anaconda3\lib\site-packages (from fastapi<1->mlflow-skinny==3.8.1->mlflow) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\adiag\anaconda3\lib\site-packages (from fastapi<1->mlflow-skinny==3.8.1->mlflow) (0.0.4)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\adiag\anaconda3\lib\site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\adiag\anaconda3\lib\site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\adiag\anaconda3\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in c:\users\adiag\anaconda3\lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\adiag\anaconda3\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.8.1->mlflow) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\adiag\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.8.1->mlflow) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\adiag\anaconda3\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\adiag\anaconda3\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\adiag\anaconda3\lib\site-packages (from graphene<4->mlflow) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\adiag\anaconda3\lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in c:\users\adiag\appdata\roaming\python\python313\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in c:\users\adiag\anaconda3\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.8.1->mlflow) (3.21.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\adiag\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\adiag\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\adiag\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\adiag\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\adiag\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\adiag\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (3.2.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\adiag\anaconda3\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.8.1->mlflow) (0.60b1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\adiag\anaconda3\lib\site-packages (from pandas<3->mlflow) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\adiag\anaconda3\lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\adiag\anaconda3\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.8.1->mlflow) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\adiag\anaconda3\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.8.1->mlflow) (2.27.1)
# Requirement already satisfied: six>=1.5 in c:\users\adiag\appdata\roaming\python\python313\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\adiag\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\adiag\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\adiag\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\adiag\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow) (0.4.8)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\adiag\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\adiag\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\adiag\anaconda3\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.1.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\adiag\anaconda3\lib\site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.8.1->mlflow) (4.7.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\adiag\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.8.1->mlflow) (1.3.0)
# Requirement already satisfied: h11>=0.8 in c:\users\adiag\anaconda3\lib\site-packages (from uvicorn<1->mlflow-skinny==3.8.1->mlflow) (0.16.0)
# Requirement already satisfied: pycparser in c:\users\adiag\anaconda3\lib\site-packages (from cffi>=1.12->cryptography<47,>=43.0.0->mlflow) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\adiag\anaconda3\lib\site-packages (from Jinja2>=3.1.2->Flask<4->mlflow) (3.0.2)

# %%
mlflow.set_experiment("First Experiment")
#mlflow.set_tracking_uri(uri="http://127.0.0.1:5000/")

with mlflow.start_run(run_name = 'First_exp'):
    mlflow.log_params(params)
    mlflow.log_metrics({
        'accuracy': report_dict['accuracy'],
        'recall_class_0': report_dict['0']['recall'],
        'recall_class_1': report_dict['1']['recall'],
        'f1_score_macro': report_dict['macro avg']['f1-score']
    })
    mlflow.sklearn.log_model(lr, "Logistic Regression")
# Out:
# 2026/02/05 16:42:47 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.schemas
# 2026/02/05 16:42:47 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.tables
# 2026/02/05 16:42:47 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.types
# 2026/02/05 16:42:47 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.constraints
# 2026/02/05 16:42:47 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.defaults
# 2026/02/05 16:42:47 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.comments
# 2026/02/05 16:42:47 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/02/05 16:42:47 INFO mlflow.store.db.utils: Updating database tables
# 2026/02/05 16:42:47 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/02/05 16:42:47 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026/02/05 16:42:47 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/02/05 16:42:47 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026/02/05 16:42:48 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
